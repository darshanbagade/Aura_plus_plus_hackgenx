# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 974.8/974.8 kB 9.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 73.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 54.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 45.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 84.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !pip install gitpython matplotlib numpy opencv-python pillow psutil PyYAML requests scipy thop torch torchvision tqdm ultralytics pandas seaborn setuptools filterpy scikit-image lap
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.0/178.0 kB 15.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 72.6 MB/s eta 0:00:00
# ...
#   Created wheel for filterpy: filename=filterpy-1.4.5-py3-none-any.whl size=110460 sha256=111d30460dbf71d0f3f4699836c68beb4acf1202fbf6edaabbc4679b4b37faef
#   Stored in directory: /root/.cache/pip/wheels/12/dc/3c/e12983eac132d00f82a20c6cbe7b42ce6e96190ef8fa2d15e1
# Successfully built filterpy
# ...

# %%
# !curl -L "https://universe.roboflow.com/ds/2TpPmoFZ1V?key=toE7pUZnS9" -o roboflow.zip
# !unzip roboflow.zip
# !rm roboflow.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: train/labels/images_50_jpeg_jpg.rf.348eead5a06de589e82c8c6cc7dbb594.txt
#  extracting: train/labels/images_50_jpeg_jpg.rf.4093275fc04a5da44bcfcc4797e79e20.txt
#  extracting: train/labels/images_50_jpeg_jpg.rf.bd116d237fe0327be699e0f5431130c2.txt
#   inflating: train/labels/images_52_jpeg_jpg.rf.1299276d9b29be96b09acd70fea29d83.txt
#   inflating: train/labels/images_52_jpeg_jpg.rf.3d7d8ac39ae8433fbf63e96d866a3407.txt
#  extracting: train/labels/images_52_jpeg_jpg.rf.a63790e4191236a28eb96ee312e259e2.txt
#  extracting: train/labels/images_56_jpeg_jpg.rf.99c54a6d8e9c9cf4f5ec40f2e7fcc3f7.txt
#  extracting: train/labels/images_56_jpeg_jpg.rf.aaad82d1bed23cef45918e29e2c1d52b.txt
#  extracting: train/labels/images_56_jpeg_jpg.rf.cc074537061880a45cf27955ec8e9e47.txt
#   inflating: train/labels/images_59_jpeg_jpg.rf.124c49505d8b635bd884d7037275902a.txt
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content
# Out:
# data.yaml  README.dataset.txt	sample_data  train
# drive	   README.roboflow.txt	test	     valid

# %%
# !cat /content/data.yaml
# Out:
# train: ../train/images
# val: ../valid/images
# test: ../test/images
#
# nc: 5
# names: ['glass', 'metal', 'paper', 'plastic', 'undefined']
#
# roboflow:
#   workspace: proje-nkf76
#   project: atik-ayristirma
#   version: 9
#   license: CC BY 4.0
#   url: https://universe.roboflow.com/proje-nkf76/atik-ayristirma/dataset/9

# %%
# %%writefile /content/data.yaml
# train: /content/train/images
# val: /content/valid/images
# test: /content/test/images
#
# nc: 6
# names: ['0', 'c', 'garbage', 'garbage_bag', 'sampah-detection', 'trash']
# Out:
# Overwriting /content/data.yaml

# %% [markdown]
# ✅ Step 6: Train the YOLOv8 Model

# %%
from ultralytics import YOLO

# Load the base model (you can also try yolov8s.pt for slightly better accuracy)
model = YOLO("yolov8n.pt")

# Start training using your dataset
model.train(data="/content/data.yaml", epochs=30)
# Out:
# Ultralytics 8.3.109 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...
